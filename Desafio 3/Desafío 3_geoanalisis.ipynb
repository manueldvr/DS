# %% [markdown]
# # LAB: Workflow de Datos. Limpieza y sumarización de datos para el Desafío 3.
#
# ## Introducción
#
# La idea de este lab es comenzar a trabajar con los datos del Desafío 3. Vamos a tratar de comenzar con el proceso de limpieza, sumarización y análisis exploratorio del dataset de Properatti. Como recordarán, el objetivo final es el desarrollo de un tasador automático a ser aplicado a las próximas propiedades que sean comercializadas por la empresa mediante un modelo de regresión. Como verán, el dataset está sumamente "sucio" y require un intenso proceos de limpieza.
#
# El dataset contiene información referida al primer semestre de 2017 de las propiedades comercializables por la empresa:
#
# * Fecha de creación
# * Tipo de la propiedad (house, apartment, ph)
# * Operación del aviso (sell, rent)
# * Nombre del lugar
# * Nombre del lugar + nombre de sus ‘padres’
# * ID de geonames del lugar (si está disponible)
# * Latitud,Longitud
# * Precio original del aviso
# * Moneda original del aviso (ARS, USD)
# * Precio del aviso en moneda local (ARS)
# * Precio aproximado en USD
# * Superficie en m²
# * Superficie cubierta en m²
# * Precio en USD/m²
# * Precio por m²
# * N° de piso, si corresponde
# * Ambientes
# * URL en Properati
# * Descripción
# * Título
# * URL de un thumbnail de la primer foto
#
#
# Una vez terminada la limpieza, aquellos que se animen pueden empezar a probar algunos modelos simples de regresión.
#
#
# ## Objetivos de aprendizaje
#
# * Practicar técnicas de limpieza de datos de tipo texto
# * Practicar conversiones de tipo de dato
# * Practicar rellenar datos faltantes con 0s o promedios
# * Practicar técnicas para trabajo con datos categóricos
# * Transformar datos a información útil
# * Realizar un primer análisis exploratorio
# * BONUS: realizar un primer modelo de regresión

# %%
% matplotlib inline
import matplotlib.pyplot as plt
import datetime
import numpy as np
import pandas as pd
import re
import seaborn as sns

# %% [markdown]
# Maps API e imports

# %%
import googlemaps
#
#   api_key='AIzaSyAdArM6h_HFIE_FoAilIFMcmOSk75KPh3Q'
#
import gmaps as gm
gm.configure(api_key='AIzaSyCxW4Et1RnWgU0uimo6NkzgX9diMCTZQU0') #

# %%
# Cargar la datos de propiedades:
df = pd.read_csv('properatti.csv')  # DATOS DE PROPIEDADES EN VENTA PROPERATI

# %% [markdown]
# Datos de servicios de transporte por Buenos Aires Data:

# %%
# Buenos Aires Data:
subte = pd.read_csv('estaciones-de-subte.csv',delimiter=',')
metrobus = pd.read_csv('estaciones-de-metrobus.csv',delimiter=';')
ferrocarril = pd.read_csv('estaciones-de-ferrocarril.csv',delimiter=';')

# %%
subte.rename(columns={'X':'lon','Y':'lat','ESTACION':'nombre'},inplace=True)
metrobus.rename(columns={'X':'lon','Y':'lat','NOMBRE':'nombre'},inplace=True)
ferrocarril.rename(columns={'LNG':'lon','LAT':'lat','NOMBRE':'nombre'},inplace=True)

# %%
subte[['lon','lat','nombre']].sample(5)
# Out:
#           lon        lat                  nombre
# 44 -58.377581 -34.612849                BELGRANO
# 4  -58.406036 -34.608935  ONCE - 30 DE DICIEMBRE
# 53 -58.411294 -34.588237                  BULNES
# 59 -58.426789 -34.627015            AV. LA PLATA
# 2  -58.402323 -34.623092              HUMBERTO 1

# %%
ferrocarril[['lon','lat','nombre']].sample(5)
# Out:
#           lon        lat                nombre
# 46 -58.446516 -34.543778  CIUDAD UNIVERSITARIA
# 32 -58.466639 -34.590413            G. ARTIGAS
# 25 -58.465298 -34.627581                FLORES
# 36 -58.480222 -34.632203              FLORESTA
# 29 -58.455464 -34.586953      FEDERICO LACROZE

# %%
metrobus[['lon','lat','nombre']].sample(5)
# Out:
#            lon        lat            nombre
# 189 -58.369245 -34.616457  AV INDEPENDENCIA
# 58  -58.476863 -34.688947           MONTIEL
# 168 -58.444496 -34.570101           OLLEROS
# 94  -58.421562 -34.656710             VEDIA
# 88  -58.437801 -34.655649            VARELA

# %%
subte['color'] = 'green'

# %%
ferrocarril['color'] = 'red'

# %%
metrobus['color'] = 'lime'

# %%
max_lat = ferrocarril['lat'].max()
min_lat = ferrocarril['lat'].min()
max_lon = ferrocarril['lon'].max()
min_lon = ferrocarril['lon'].min()

# %%
subte.head(5)
# Out:
#          lon        lat   ID                  nombre LINEA  color
# 0 -58.398928 -34.635750  1.0                 CASEROS     H  green
# 1 -58.400970 -34.629376  2.0                  INCLAN     H  green
# 2 -58.402323 -34.623092  3.0              HUMBERTO 1     H  green
# 3 -58.404732 -34.615242  4.0               VENEZUELA     H  green
# 4 -58.406036 -34.608935  5.0  ONCE - 30 DE DICIEMBRE     H  green

# %%
for i in range(0,5):
    df = df.append(metrobus)
    df = df.append(ferrocarril)
    df = df.append(subte)

# %%
df_subte_locations = subte.loc[:,['lat','lon']]
df_ferrocarril_locations = ferrocarril.loc[:,['lat','lon']]
df_metrobus_locations = metrobus.loc[:,['lat','lon']]

fig = gm.figure(map_type='ROADMAP')
subte_symbols = gm.symbol_layer(
        df_subte_locations, fill_color='red', stroke_color='red')
ferrocarril_symbols = gm.symbol_layer(
        df_ferrocarril_locations, fill_color='green', stroke_color='green')
metrobus_symbols = gm.symbol_layer(
        df_metrobus_locations, fill_color='blue', stroke_color='blue')

fig.add_layer(subte_symbols)
fig.add_layer(ferrocarril_symbols)
fig.add_layer(metrobus_symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
figH = gm.figure(map_type='ROADMAP')
heatmap_layer_subte = gm.heatmap_layer(df_subte_locations)
heatmap_layer_ferrocarril = gm.heatmap_layer(df_ferrocarril_locations)
heatmap_layer_metrobus = gm.heatmap_layer(df_metrobus_locations)
#heatmap_layer.max_intensity = 100
heatmap_layer_subte.point_radius = 25
heatmap_layer_ferrocarril.point_radius = 25
heatmap_layer_metrobus.point_radius = 25
figH.add_layer(heatmap_layer)
figH.add_layer(heatmap_layer_ferrocarril)
figH.add_layer(heatmap_layer_metrobus)
figH
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Limpiar el dataset
# Practiquemos nuestras capacidades para realizar limpieza de datos con el dataset de ventas de propiedades de Properatti. Si no recuerdan cómo hacer alguna de estas tareas, busquen en Internet o en clases anteriores de manipulación de datos.
#
# Buscamos que completen las siguientes tareas:
# * Quitar columnas redundantes
# * Convertir las variables categóricas numéricas a integer
# * Lidiar con los valores perdidos y/o erróneos en algunas variables clave:
#
#     + en este punto podría ser interesante realizar algo ligeramente más complejo que un simple rellenado en función de medias. Podría eventualmente imputar en función de medias condicionadas.
#         * por ejemplo, los campos `lat` y `long` tienen, también, muchos casos perdidos. Quizás una estrategia posible sería tratar de imputar las coordenadas con la media de los casos en el mismo `place_name` -barrio-.
#     + también podrían evaluar la posibilidad de extraer alguna información para completar los datos perdidos del campo "description" que contiene texto del aviso.
#         * por ejemplo, el campo `rooms` tiene una altísima cantidad de missing. Podrían intentar usando alguna expresión regex extraer información

# %%
#Analizamos las columnas, los tipos de datos y la cantidad de datos nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122945 entries, 0 to 85
# Data columns (total 41 columns):
# BARRIO                        235 non-null object
# CALLE1                        1060 non-null object
# CALLE2                        130 non-null object
# COMUNA                        235 non-null object
# EMPRESA                       215 non-null object
# ID                            1725 non-null float64
# INAUGURA                      1060 non-null object
# INTERSEC                      1045 non-null object
# LINEA                         665 non-null object
# LINEA_2                       235 non-null object
# LIN_SENT_N                    725 non-null object
# LIN_SENT_S                    690 non-null object
# METROBUS                      1060 non-null object
# Unnamed: 0                    121220 non-null float64
# color                         1725 non-null object
# country_name                  121220 non-null object
# currency                      100809 non-null object
# description                   121218 non-null object
# expenses                      14262 non-null float64
# floor                         7899 non-null float64
# geonames_id                   102503 non-null float64
# image_thumbnail               118108 non-null object
# lat                           71395 non-null float64
# lat-lon                       69670 non-null object
# lon                           71395 non-null float64
# nombre                        1725 non-null object
# operation                     121220 non-null object
# place_name                    121197 non-null object
# place_with_parent_names       121220 non-null object
# price                         100810 non-null float64
# price_aprox_local_currency    100810 non-null float64
# price_aprox_usd               100810 non-null float64
# price_per_m2                  87658 non-null float64
# price_usd_per_m2              68617 non-null float64
# properati_url                 121220 non-null object
# property_type                 121220 non-null object
# rooms                         47390 non-null float64
# state_name                    121220 non-null object
# surface_covered_in_m2         101313 non-null float64
# surface_total_in_m2           81892 non-null float64
# title                         121220 non-null object
# dtypes: float64(15), object(26)
# memory usage: 39.4+ MB

# %% [markdown]
# # Filtrar los Datos
#
# En general, los mdoelos de precios suelen tener un carácter local. Es por eso que deberán elegir alguna zona o provincia para trabajar y estimar el modelo en base a dicha selección.

# %%
#Validamos que no tengamos duplicados
df.drop_duplicates(subset=['lat-lon','properati_url','description']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121221 entries, 0 to 0
# Data columns (total 41 columns):
# BARRIO                        0 non-null object
# CALLE1                        1 non-null object
# CALLE2                        0 non-null object
# COMUNA                        0 non-null object
# EMPRESA                       0 non-null object
# ID                            1 non-null float64
# INAUGURA                      1 non-null object
# INTERSEC                      1 non-null object
# LINEA                         0 non-null object
# LINEA_2                       0 non-null object
# LIN_SENT_N                    1 non-null object
# LIN_SENT_S                    1 non-null object
# METROBUS                      1 non-null object
# Unnamed: 0                    121220 non-null float64
# color                         1 non-null object
# country_name                  121220 non-null object
# currency                      100809 non-null object
# description                   121218 non-null object
# expenses                      14262 non-null float64
# floor                         7899 non-null float64
# geonames_id                   102503 non-null float64
# image_thumbnail               118108 non-null object
# lat                           69671 non-null float64
# lat-lon                       69670 non-null object
# lon                           69671 non-null float64
# nombre                        1 non-null object
# operation                     121220 non-null object
# place_name                    121197 non-null object
# place_with_parent_names       121220 non-null object
# price                         100810 non-null float64
# price_aprox_local_currency    100810 non-null float64
# price_aprox_usd               100810 non-null float64
# price_per_m2                  87658 non-null float64
# price_usd_per_m2              68617 non-null float64
# properati_url                 121220 non-null object
# property_type                 121220 non-null object
# rooms                         47390 non-null float64
# state_name                    121220 non-null object
# surface_covered_in_m2         101313 non-null float64
# surface_total_in_m2           81892 non-null float64
# title                         121220 non-null object
# dtypes: float64(15), object(26)
# memory usage: 38.8+ MB

# %%
def obtener_superficie(x):
    if ~np.isnan(x['surface_covered_in_m2']):
        return x['surface_covered_in_m2']
    elif ~np.isnan(x['surface_total_in_m2']):
        return x['surface_total_in_m2']
    else:
        return np.nan

# %%
def calcular_precio(x):
    if ~np.isnan(x['price_aprox_usd']):
        return x['price_aprox_usd']
    elif ~np.isnan(x['price_per_m2'])  :
        return x['price_per_m2'] * df['superficie_cubierta']
    elif ~np.isnan(x['price_usd_per_m2']): 
        return x['price_usd_per_m2'] * df['superficie_cubierta']
    else:
        return np.nan

# %%
def obtener_ambientes(x):
    try:
        x = x.lower()
        if (x.rfind("amb") != -1) or (x.rfind("dorm") != -1):
            if (x.rfind("amb") != -1):
                pos = x.rfind("amb")            
            else:
                pos = x.rfind("dorm")  #ver si hay que sumarle 1 ambiente cuando solo diga cant de dormitorios
                
            try:
                return (np.float64(x[pos -2]))
            except ValueError:
                if "monoambiente" in x:
                    return 1.0
                elif ("dos amb" in x) or ("dos dorm" in x):
                    return 2.0
                elif ("tres amb" in x) or ("tres dorm" in x):
                    return 3.0
                elif ("cuatro amb" in x) or ("cuatro dorm" in x):
                    return 4.0
                elif ("cinco amb" in x) or ("cinco dorm" in x):
                    return 5.0
                elif ("seis amb" in x) or ("seis dorm" in x):
                    return 6.0
                return 0
    except AttributeError:
        return None

# %%
def obtener_balcon(x):
    try:
        x = x.lower()
        if ("balcon" in x) or ("balcón" in x):
            return 1
        else:
            return 0
    except AttributeError:
        return 0

# %%
def obtener_cochera(x):
    try:
        x = x.lower()
        if ("cochera" in x):
            return 1
        else:
            return 0
    except AttributeError:
        return 0

# %%
#Se crea la columna ambientes extrayendo los datos desde la columna descripcion
df['ambientes'] = df['description'].apply(obtener_ambientes)

# %%
#Si en la descripcion no se encontraron datos intentamos con la columna title
df.loc[df['ambientes']==0,'ambientes'] = df.loc[df['ambientes']==0,'title'].apply(obtener_ambientes)

# %%
#Si no se encontraron ambientes ni en description ni en title se copia el valor de la columna rooms
df.loc[(np.isnan(df['ambientes'])),'ambientes'] = df.loc[(np.isnan(df['ambientes'])),'rooms']

# %%
#Agregamos columna dummy balcon
df['balcon'] = df['description'].apply(obtener_balcon)

# %%
#Agregamos columna dummy cochera
df['cochera'] = df['description'].apply(obtener_cochera)

# %%
#Agregamos columna superficie_cubierta
df['superficie_cubierta'] = df.apply(obtener_superficie,axis=1)

# %%
#Calculamos el precio
df['precio'] = df.apply(calcular_precio,axis=1)

# %%
#Calculamos el tipo de cambio
#df['tipo_cambio'] = df['price'] / df['price_aprox_usd']

# %%
#Filtramos por los departamentos a la venta en Capital Federal
df_prop = df[(df['operation']== 'sell') & (df['state_name']== 'Capital Federal') & (df['property_type']== 'apartment')]

# %%
#Borramos las filas que no tengan precio ni superficie_cubierta
df_prop = df_prop.dropna(axis=0 ,how='any',subset=['precio','superficie_cubierta'])

# %%
#Tomamos solo las columnas que nos interesan
df_prop = df_prop.loc[:,['place_name','geonames_id','lat-lon','lat','lon','floor','ambientes','expenses','description','title','superficie_cubierta','precio','cochera','balcon']].sort_values(by='place_name')

# %%
#Modificamos el nombre de las columnas
df_prop.columns = ['barrio','geonames_id','lat-lon','lat','lon','piso','ambientes','expensas','descripcion','titulo','superficie_cubierta','precio','cochera','balcon']

# %% [markdown]
# # Análisis exploratorio
#
# Como estamos intentando predecir precios por metro cuadrado es importante realizar una primera vista y exploración de los datos.

# %%
df_prop.head(10)
# Out:
#        barrio  geonames_id                        lat-lon        lat  \
# 17996  Abasto          NaN        -34.6063725,-58.4124011 -34.606372
# 71972  Abasto          NaN  -34.6005862561,-58.4107692116 -34.600586
# 71959  Abasto          NaN  -34.6005862561,-58.4107692116 -34.600586
# 92574  Abasto          NaN                            NaN        NaN
# 56135  Abasto          NaN         -34.602334,-58.4073109 -34.602334
# 23523  Abasto          NaN        -34.6045227,-58.4117071 -34.604523
# 92381  Abasto          NaN                            NaN        NaN
# 98082  Abasto          NaN                            NaN        NaN
# 73189  Abasto          NaN        -34.6067402,-58.4135153 -34.606740
# 98094  Abasto          NaN                            NaN        NaN
#
#              lon  piso  ambientes  expensas  \
# 17996 -58.412401   NaN        1.0     971.0
# 71972 -58.410769   NaN        NaN       NaN
# 71959 -58.410769   NaN        NaN       NaN
# 92574        NaN   NaN        2.0       NaN
# 56135 -58.407311   NaN        3.0    2900.0
# 23523 -58.411707   NaN        2.0    1000.0
# 92381        NaN   NaN        2.0       NaN
# 98082        NaN   NaN        1.0    1900.0
# 73189 -58.413515   NaN        1.0       NaN
# 98094        NaN   NaN        1.0    1900.0
#
#                                              descripcion  \
# 17996  Monoambiente en tres niveles con entrepiso, a ...
# 71972  Excelente emprendimiento en muy buena ubicació...
# 71959  Excelente emprendimiento en muy buena ubicació...
# 92574  Depto de dos dormitorios, baño completo, gran ...
# 56135  Venta de Departamento 3 AMBIENTES en Abasto, C...
# 23523  CODIGO: 3918-1 ubicado en: Aguero 800 -  Publi...
# 92381  Departamento en venta de 2 Dormitorios con bal...
# 98082  OPORTUNIDAD! Hermoso monoambiente AMOBLADO en ...
# 73189  Capital Brokers Propiedades |  o 15-Dirección:...
# 98094  OPORTUNIDAD! Hermoso monoambiente AMOBLADO en ...
#
#                                                   titulo  superficie_cubierta  \
# 17996                              DEPARTAMENTO EN VENTA                 41.0
# 71972                              Departamento - Abasto                 37.0
# 71959                              Departamento - Abasto                 37.0
# 92574                              Departamento - Abasto                 83.0
# 56135                              DEPARTAMENTO EN VENTA                 58.0
# 23523  Semipiso de 2 ambientes, con Balcón terraza y ...                 46.0
# 92381  Oportunidad - Depto de 2 Dormitorios con balcó...                 60.0
# 98082  Departamento 1 AMBIENTE, impecable con Ameniti...                 31.0
# 73189                                   Venta 1 ambiente                 37.0
# 98094         Departamento MONOAMBIENTE AMOBLADO- Abasto                 31.0
#
#           precio  cochera  balcon
# 17996   67000.00        0       0
# 71972   82000.00        1       0
# 71959   82000.00        1       0
# 92574  160000.00        0       1
# 56135  139500.00        0       1
# 23523  145000.00        1       1
# 92381   87714.87        1       1
# 98082   97000.00        0       1
# 73189  102366.00        0       0
# 98094   97000.00        0       1

# %%
df_prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23777 entries, 17996 to 56195
# Data columns (total 14 columns):
# barrio                 23777 non-null object
# geonames_id            22799 non-null float64
# lat-lon                17888 non-null object
# lat                    17888 non-null float64
# lon                    17888 non-null float64
# piso                   2766 non-null float64
# ambientes              20832 non-null float64
# expensas               5905 non-null float64
# descripcion            23777 non-null object
# titulo                 23777 non-null object
# superficie_cubierta    23777 non-null float64
# precio                 23777 non-null float64
# cochera                23777 non-null int64
# balcon                 23777 non-null int64
# dtypes: float64(8), int64(2), object(4)
# memory usage: 2.7+ MB

# %%
df_t = df_prop.groupby(by=['barrio']).precio.describe()
df_t.head()
# Out:
#            count           mean            std      min       25%       50%  \
# barrio
# Abasto      76.0  125285.919342   61355.937605  38000.0   83480.5  114750.0
# Agronomía   27.0  129110.185185   39659.321256  69595.0  102500.0  127000.0
# Almagro    849.0  152803.328693  115866.705422   5500.0   85000.0  125000.0
# Balvanera  549.0  132672.884809   89443.700080  45000.0   80000.0  116000.0
# Barracas   299.0  166882.166388  122853.088934  40000.0   89000.0  131000.0
#
#                 75%        max
# barrio
# Abasto     150058.0   440000.0
# Agronomía  140000.0   225000.0
# Almagro    175000.0   999900.0
# Balvanera  150000.0   980000.0
# Barracas   202500.0  1419000.0

# %%
#Filtramos por dispercion y medias para elegir los barrios que el algoritmo va a tasar el objetivo es encontrar la menor varianza

df_t[df_t['std']<6.4751e+04]
# Out:
#                    count           mean           std       min        25%  \
# barrio
# Abasto              76.0  125285.919342  61355.937605  38000.00   83480.50
# Agronomía           27.0  129110.185185  39659.321256  69595.00  102500.00
# Chacarita          181.0  115302.742099  56718.252149  50000.00   85790.00
# Constitución       170.0   90931.366176  52103.548977  23555.14   70000.00
# Floresta           274.0  118684.873577  51145.216694   5608.36   85000.00
# Monte Castro        41.0  117700.000000  43385.106892  60000.00   88000.00
# Parque Avellaneda   22.0  100427.272727  36932.850029   9500.00   77250.00
# Parque Chas         34.0  108961.705882  31036.409462  25000.00   93650.00
# Paternal            94.0  107255.260106  49881.651858  55000.00   75000.00
# Pompeya             16.0   86041.421875  41036.174680  42062.75   54400.00
# Velez Sarsfield     10.0  105139.900000  41847.511914  52000.00   73975.00
# Versalles           18.0  140883.333333  56863.078583  68000.00  108750.00
# Villa Lugano        78.0   89916.564615  48656.308250  24300.00   60000.00
# Villa Ortuzar       66.0  126328.787879  61226.411508  74000.00   97250.00
# Villa Pueyrredón   104.0  128990.085385  49744.382208  10274.52   94650.00
# Villa Real           8.0  152625.000000  39449.560925  79000.00  145250.00
# Villa Santa Rita    30.0  112458.333333  59505.517106  60000.00   74125.00
# Villa Soldati        8.0   64065.355000  15356.841525  39000.00   53642.13
#
#                         50%       75%       max
# barrio
# Abasto             114750.0  150058.0  440000.0
# Agronomía          127000.0  140000.0  225000.0
# Chacarita           96000.0  130000.0  450000.0
# Constitución        81900.0   96870.0  419000.0
# Floresta           109750.0  139500.0  359999.0
# Monte Castro       105000.0  137500.0  245000.0
# Parque Avellaneda   98250.0  124625.0  200000.0
# Parque Chas        103900.0  127050.0  195258.0
# Paternal            91525.5  128375.0  375000.0
# Pompeya             70000.0  106250.0  160000.0
# Velez Sarsfield     97000.0  134625.0  172999.0
# Versalles          127000.0  163500.0  295000.0
# Villa Lugano        76500.0  105000.0  350000.0
# Villa Ortuzar      113500.0  135375.0  520000.0
# Villa Pueyrredón   121356.5  150215.0  325000.0
# Villa Real         152000.0  163750.0  220000.0
# Villa Santa Rita    92450.0  132000.0  375000.0
# Villa Soldati       69000.0   72500.0   86000.0

# %% [markdown]
# Los barrios son:<br>Agronomia,<br>Chacarita (a ver),<br>Paternal,<br>Parque Chas,<br>Villa Ortuzar y<br>Villa Pueyrredon.<br> y conforman el mercado relevante (Oferta)

# %%
df_selecc_barrios_Prop = df_prop.loc[(df_prop['barrio']=='Agronomía') 
                                    | (df_prop['barrio']=='Chacarita')
                                    | (df_prop['barrio']=='Paternal')
                                    | (df_prop['barrio']=='Parque Chas')
                                    | (df_prop['barrio']=='Villa Ortuzar')
                                    | (df_prop['barrio']=='Villa Pueyrredon') ]
# Out:
#            barrio  geonames_id                        lat-lon        lat  \
# 30976   Agronomía    3436487.0        -34.5905608,-58.4802571 -34.590561
# 45460   Agronomía    3436487.0  -34.5862898501,-58.4714038418 -34.586290
# 45461   Agronomía    3436487.0  -34.5862898501,-58.4714038418 -34.586290
# 41312   Agronomía    3436487.0          -34.591557,-58.496629 -34.591557
# 62137   Agronomía    3436487.0         -34.595105,-58.4962184 -34.595105
# 97195   Agronomía    3436487.0  -34.6038624605,-58.4626840119 -34.603862
# 63839   Agronomía    3436487.0  -34.5898418174,-58.4896510349 -34.589842
# 59932   Agronomía    3436487.0        -34.5924699,-58.4944042 -34.592470
# 112866  Agronomía    3436487.0  -34.6004426729,-58.4874138526 -34.600443
# 63737   Agronomía    3436487.0        -34.5900008,-58.4899729 -34.590001
# 59270   Agronomía    3436487.0           -34.590568,-58.48041 -34.590568
# 64070   Agronomía    3436487.0  -34.5862898501,-58.4714038418 -34.586290
# 57243   Agronomía    3436487.0          -34.591764,-58.490803 -34.591764
# 116440  Agronomía    3436487.0           -34.594262,-58.49498 -34.594262
# 72187   Agronomía    3436487.0  -34.5884646379,-58.4854280597 -34.588465
# 40073   Agronomía    3436487.0          -34.591312,-58.478474 -34.591312
# 55646   Agronomía    3436487.0          -34.585972,-58.490251 -34.585972
# 33218   Agronomía    3436487.0        -34.5987605,-58.4809236 -34.598760
# 382     Agronomía    3436487.0        -34.5924699,-58.4944042 -34.592470
# 63685   Agronomía    3436487.0  -34.5862898501,-58.4714038418 -34.586290
# 56248   Agronomía    3436487.0        -34.5989348,-58.4838632 -34.598935
# 60166   Agronomía    3436487.0          -34.585972,-58.490251 -34.585972
# 63683   Agronomía    3436487.0  -34.5862898501,-58.4714038418 -34.586290
# 12393   Agronomía    3436487.0   -34.5943658677,-58.494954314 -34.594366
# 5994    Agronomía    3436487.0          -34.592467,-58.493142 -34.592467
# 41141   Agronomía    3436487.0          -34.599007,-58.481086 -34.599007
# 63684   Agronomía    3436487.0        -34.5924699,-58.4944042 -34.592470
# 108906  Chacarita    3435506.0  -34.5807758367,-58.4541714712 -34.580776
# 72603   Chacarita    3435506.0         -34.615111,-58.4967729 -34.615111
# 61231   Chacarita    3435506.0        -34.5849804,-58.4542085 -34.584980
# 29436   Chacarita    3435506.0        -34.5922408,-58.4470178 -34.592241
# 72581   Chacarita    3435506.0         -34.615111,-58.4967729 -34.615111
# 32804   Chacarita    3435506.0           -34.58551,-58.453844 -34.585510
# 61229   Chacarita    3435506.0        -34.5849804,-58.4542085 -34.584980
# 23270   Chacarita    3435506.0          -34.584261,-58.453621 -34.584261
# 81188   Chacarita    3435506.0  -34.5907407691,-58.4487541204 -34.590741
# 23269   Chacarita    3435506.0          -34.584261,-58.453621 -34.584261
# 61230   Chacarita    3435506.0        -34.5849804,-58.4542085 -34.584980
# 72592   Chacarita    3435506.0         -34.615111,-58.4967729 -34.615111
# 63611   Chacarita    3435506.0        -34.5804527,-58.4509198 -34.580453
# 109193  Chacarita    3435506.0                            NaN        NaN
# 111543  Chacarita    3435506.0           -34.58412,-58.453668 -34.584120
# 61233   Chacarita    3435506.0        -34.5849804,-58.4542085 -34.584980
# 44534   Chacarita    3435506.0         -34.5925724,-58.446712 -34.592572
# 80743   Chacarita    3435506.0  -34.5844433253,-58.4533612449 -34.584443
# 56109   Chacarita    3435506.0        -34.5896791,-58.4476248 -34.589679
# 94110   Chacarita    3435506.0                            NaN        NaN
# 58801   Chacarita    3435506.0        -34.5933803,-58.4422054 -34.593380
# 94103   Chacarita    3435506.0                            NaN        NaN
# 10453   Chacarita    3435506.0        -34.5932844,-58.4541388 -34.593284
#
#               lon  piso  ambientes  expensas  \
# 30976  -58.480257   NaN        2.0   15000.0
# 45460  -58.471404   NaN        2.0       NaN
# 45461  -58.471404   NaN        2.0       NaN
# 41312  -58.496629  29.0        4.0       NaN
# 62137  -58.496218   NaN        3.0       NaN
# 97195  -58.462684   NaN        1.0    1800.0
# 63839  -58.489651   NaN        1.0       NaN
# 59932  -58.494404   NaN        3.0       NaN
# 112866 -58.487414   NaN        NaN    1553.0
# 63737  -58.489973   NaN        1.0       NaN
# 59270  -58.480410   NaN        0.0       NaN
# 64070  -58.471404   NaN        3.0       NaN
# 57243  -58.490803   NaN        3.0       NaN
# 116440 -58.494980   NaN        2.0    1000.0
# 72187  -58.485428   NaN        NaN    1200.0
# 40073  -58.478474   NaN        0.0       NaN
# 55646  -58.490251   NaN        2.0       NaN
# 33218  -58.480924   NaN        4.0       NaN
# 382    -58.494404   NaN        2.0       NaN
# 63685  -58.471404   NaN        2.0       NaN
# 56248  -58.483863   NaN        3.0    1500.0
# 60166  -58.490251   NaN        2.0       NaN
# 63683  -58.471404   NaN        3.0       NaN
# 12393  -58.494954   NaN        2.0     800.0
# 5994   -58.493142   NaN        3.0       NaN
# 41141  -58.481086   NaN        3.0       NaN
# 63684  -58.494404   NaN        3.0       NaN
# 108906 -58.454171   NaN        2.0     800.0
# 72603  -58.496773   NaN        2.0       NaN
# 61231  -58.454208   5.0        1.0       NaN
# 29436  -58.447018   NaN        4.0       NaN
# 72581  -58.496773   NaN        2.0       NaN
# 32804  -58.453844   NaN        1.0       NaN
# 61229  -58.454208   4.0        1.0       NaN
# 23270  -58.453621   NaN        2.0       NaN
# 81188  -58.448754   NaN        0.0    1200.0
# 23269  -58.453621   NaN        2.0       NaN
# 61230  -58.454208   6.0        1.0       NaN
# 72592  -58.496773   NaN        2.0       NaN
# 63611  -58.450920   NaN        1.0       NaN
# 109193        NaN   NaN        1.0    1500.0
# 111543 -58.453668   7.0        1.0       NaN
# 61233  -58.454208   4.0        1.0       NaN
# 44534  -58.446712   NaN        1.0       NaN
# 80743  -58.453361   NaN        1.0       NaN
# 56109  -58.447625   NaN        2.0     900.0
# 94110         NaN   NaN        2.0       NaN
# 58801  -58.442205   NaN        1.0       NaN
# 94103         NaN   NaN        2.0       NaN
# 10453  -58.454139   NaN        3.0       NaN
#
#                                               descripcion  \
# 30976   EXCELENTE DEPARTAMENTO DE 2 AMBIENTES CON BALC...
# 45460   Dpto de 2 ambientes con toilette de recepción ...
# 45461   Dpto de 2 ambientes con toilette de recepción ...
# 41312   Corredor Responsable: Lucas Federico Delgado -...
# 62137   Departamento de 3 Ambientes con Patio al Frent...
# 97195   EXCELENTE MONOAMBIENTE A ESTRENAR. UBICACIÓN E...
# 63839   CODIGO: 3457-SOLANO2447 ubicado en: Solano Lop...
# 59932   Departamentos de 3 ambientes al frente con bal...
# 112866  *** CONDARCO 3000, entre Melincué y Nogoya ***...
# 63737   Solano Lopez 2400, es un edificio de 3 pisos.E...
# 59270   Corredor Responsable: Gabriel Sola - CUCICBA 2...
# 64070   Dpto de 2 ambientes con toilette de recepción ...
# 57243   Corredor Responsable: Martin Macagno - CUCICBA...
# 116440  CODIGO: 580-nazca3600 ubicado en: NAZCA 3600 -...
# 72187   Excelente departamento de 3 ambientes al frent...
# 40073   Corredor Responsable: Ariel Champanier - C.U.C...
# 55646   Hermosisimo departamento con dos balcones, uno...
# 33218   DEPARTAMENTO DE 4 AMBIENTES AL FRENTE CON BALC...
# 382     Agronomía, 2 ambientes contrafrente, con coche...
# 63685   Dpto de 2 ambientes con toilette de recepción ...
# 56248   Venta de Departamento 3 AMBIENTES en Agronomía...
# 60166   Hermosisimo departamento con dos balcones, uno...
# 63683   Dpto de 2 ambientes. Totalmente externo. Incre...
# 12393   Venta de Departamento 2 AMBIENTES al frente  e...
# 5994    Corredor Responsable: Mauro Marvisi - CUCICBA ...
# 41141   Corredor Responsable: Marcelo Trujillo - CUCIC...
# 63684   Dpto de 2 ambientes  totalmente externo. Incre...
# 108906  Depto. tipo PH al frente 2 ambientes. Bajas ex...
# 72603      VENTA - DEPARTAMENTO - 2 AMBIENTES - CHACARITA
# 61231   Venta de Departamento MONOAMBIENTE DIVISIBLE e...
# 29436   DEPARTAMENTO 4 AMBIENTES CHACARITALuminoso dep...
# 72581      VENTA - DEPARTAMENTO - 2 AMBIENTES - CHACARITA
# 32804   ---- SE ENTREGAN EN DICIEMBRE DE 2017 - AV FOR...
# 61229   Venta de Departamento MONOAMBIENTE DIVISIBLE e...
# 23270   Venta - Departamento - Argentina, Buenos Aires...
# 81188   Hermoso mono ambiente a estrenar con sesión de...
# 23269   Venta - Departamento - Argentina, Buenos Aires...
# 61230   Venta de Departamento MONOAMBIENTE DIVISIBLE e...
# 72592      VENTA - DEPARTAMENTO - 2 AMBIENTES - CHACARITA
# 63611   Venta Departamento Monoambiente en Chacarita 3...
# 109193  A estrenar - Apto profesional - Piscina con so...
# 111543  Corredor Responsable: Maria Cristina Barrionue...
# 61233   Venta de Departamento MONOAMBIENTE DIVISIBLE e...
# 44534   Luminoso  y amplísimo monoambiente . Contrafre...
# 80743   Venta con renta departamento monoambiente con ...
# 56109   Venta de Departamento DOS AMBIENTES en Chacari...
# 94110   EN CONSTRUCCIONFECHA DE ENTREGA ESTIMADA: OCTU...
# 58801   AMBIENTE DIVISIBLE CON PISOS DE PORCELANATO NA...
# 94103   EN CONSTRUCCIONFECHA DE ENTREGA ESTIMADA: OCTU...
# 10453   A 3 C/ AV. CORRIENTES, A 7 C/ SUBTE LINEA B "F...
#
#                                                    titulo  \
# 30976                                  Departamento venta
# 45460   TORRE GIGA A ESTRENAR PISO 4º 2 AMB c/ TOILETT...
# 45461   TORRE GIGA A ESTRENAR PISO 4º 2 AMB c/ TOILETT...
# 41312                SEMIPISO DE 4 AMB CON BALCÓN TERRAZA
# 62137   Luminosa Planta Baja de 3 Ambientes con Patio ...
# 97195   EXCELENTE MONO!! CON BALCON AL FRENTE, APTO CR...
# 63839    EXCELENTE DEPARTAMENTO DE 1 AMBIENTES A ESTRENAR
# 59932   AGRONOMIA 3 ambientes con cochera a estrenar. ...
# 112866  Condarco 3000 - 4 amb al frente 92 m2 -  Apto ...
# 63737                                  Departamento venta
# 59270                   Mono-Ambiente Muy luminoso 33 mts
# 64070   TORRE GIGA A ESTRENAR PISO 9º 2 AMB c/ TOILETT...
# 57243          Venta en Pozo 1 ambiente. Con financiación
# 116440  EXCELENTE DEPTO 2 AMB. COCH. OPC. FRENTE. NAZC...
# 72187               Excelente dpto.3 al frente con balcón
# 40073          Excelente Ambiente al Frente- APTO CREDITO
# 55646             Hermosisimo departamento c/ 2 balcones
# 33218   DEPARTAMENTO DE 4 AMBIENTES AL FRENTE CON BALC...
# 382     Agronomía, 2 ambientes con cochera fija a estr...
# 63685   TORRE GIGA A ESTRENAR PISO 7º 2 AMB C/BAÑO Y T...
# 56248                               DEPARTAMENTO EN VENTA
# 60166   Apto crédito - Hermosisimo departamento c/ 2 b...
# 63683   TORRE GIGA A ESTRENAR 2 AMB PISO 10º TODO EXTE...
# 12393                               DEPARTAMENTO EN VENTA
# 5994                 3 ambientes con terraza en Agronomia
# 41141        Venta 3 Ambientes Apto Crédito Av San Martín
# 63684   TORRE GIGA A ESTRENAR,  2 AMB  TODO EXTERNO DE...
# 108906  Venta dpto en PB tipo PH al fte entrada indivi...
# 72603        Excelente Depto en construcción en Chacarita
# 61231                               DEPARTAMENTO EN VENTA
# 29436                               DEPARTAMENTO EN VENTA
# 72581        Excelente Depto en construcción en Chacarita
# 32804   Av Forest Al 614 Estrenar Monoambiente C/terra...
# 61229                               DEPARTAMENTO EN VENTA
# 23270          Departamento en Venta ubicado en Chacarita
# 81188                   Hermoso mono ambiente a estrenar.
# 23269          Departamento en Venta ubicado en Chacarita
# 61230                               DEPARTAMENTO EN VENTA
# 72592        Excelente Depto en construcción en Chacarita
# 63611        Venta Departamento Monoambiente en Chacarita
# 109193  Venta Palermo: Hermoso Monoambiente a estrenar...
# 111543          Monoambiente, amplio, con balcon corrido.
# 61233                               DEPARTAMENTO EN VENTA
# 44534   Venta amplio monoambiente contrafrente vista a...
# 80743   Venta con renta - monoambiente con balcón al f...
# 56109                               DEPARTAMENTO EN VENTA
# 94110                Forest 614 - Chacarita - 2 Ambientes
# 58801   AV. JUAN B. JUSTO AL 2300- A ESTRENAR- 1 AMB- ...
# 94103                Forest 614 - Chacarita - 2 Ambientes
# 10453   EDIFICIO POCAS UNIDADES - SIN EXPENSAS - COCIN...
#
#         superficie_cubierta    precio  cochera  balcon
# 30976                  39.0   95000.0        1       1
# 45460                  47.0  124700.0        1       1
# 45461                  47.0  130700.0        1       1
# 41312                 114.0  225000.0        0       1
# 62137                  60.0  140000.0        0       0
# 97195                  30.0   81000.0        1       1
# 63839                  42.0   95000.0        0       1
# 59932                  62.0  176200.0        1       1
# 112866                 84.0  209000.0        0       0
# 63737                  38.0   95000.0        0       1
# 59270                  33.0   76000.0        0       0
# 64070                  47.0  134640.0        1       1
# 57243                  36.0   69595.0        1       0
# 116440                 52.0  110000.0        1       1
# 72187                  50.0  131000.0        0       1
# 40073                  32.0   73500.0        0       1
# 55646                  40.0  124000.0        0       1
# 33218                  67.0  130000.0        0       1
# 382                    56.0  140000.0        1       1
# 63685                  52.0  145860.0        1       1
# 56248                  60.0  140000.0        1       0
# 60166                  40.0  124000.0        0       1
# 63683                  40.0  126480.0        1       1
# 12393                  54.0  135000.0        1       1
# 5994                  111.0  210000.0        1       1
# 41141                  59.0  127000.0        0       1
# 63684                  40.0  117300.0        1       1
# 108906                 40.0   75000.0        0       0
# 72603                  44.0   90000.0        0       0
# 61231                  34.0   86000.0        1       0
# 29436                  70.0  190000.0        0       1
# 72581                  46.0   85000.0        0       0
# 32804                  37.0  100000.0        0       0
# 61229                  34.0   84500.0        1       0
# 23270                  60.0  145000.0        0       1
# 81188                  28.0   80000.0        0       1
# 23269                  60.0  140000.0        0       1
# 61230                  34.0   87500.0        1       0
# 72592                  46.0   82000.0        0       0
# 63611                  27.0   82000.0        0       1
# 109193                 35.0  100000.0        0       1
# 111543                 38.0   85000.0        0       0
# 61233                  34.0   84500.0        1       0
# 44534                  38.0   85000.0        0       1
# 80743                  33.0   81000.0        0       1
# 56109                  36.0  118000.0        0       1
# 94110                  35.0   90500.0        0       0
# 58801                  40.0   91200.0        1       1
# 94103                  35.0   86000.0        0       0
# 10453                  58.0  112000.0        0       0

# %%
df_barrios_locations = df_selecc_barrios_Prop.loc[:,['lat','lon']]
df_barrios_locations = df_barrios_locations.dropna(axis=0 ,how='any',subset=['lat','lon'])

# %%
figHeat_Prop_Transp = gm.figure(map_type='ROADMAP')

symbol_layer_Prop = gm.symbol_layer(
        df_barrios_locations, fill_color='blue', stroke_color='blue')

heatmap_layer_subte = gm.heatmap_layer(df_subte_locations)
heatmap_layer_ferrocarril = gm.heatmap_layer(df_ferrocarril_locations)
heatmap_layer_metrobus = gm.heatmap_layer(df_metrobus_locations)

heatmap_layer.max_intensity = 100
heatmap_layer_subte.point_radius = 25
heatmap_layer_ferrocarril.point_radius = 25
heatmap_layer_metrobus.point_radius = 25

figHeat_Prop_Transp.add_layer(symbol_layer_Prop)
figHeat_Prop_Transp.add_layer(heatmap_layer_subte)
figHeat_Prop_Transp.add_layer(heatmap_layer_ferrocarril)
figHeat_Prop_Transp.add_layer(heatmap_layer_metrobus)

figHeat_Prop_Transp
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Exploracion grafica sin terminar

# %%
#
sns.distplot(df_prop['precio'][(df_prop['barrio']=='Agronomía')]);

# %% [markdown]
# ## Correlaciones

# %% [markdown]
# ### Queremos observar gráficamente la correlación entre precio y superficie.
# <br> <br>
# Para superficies entre 20m2 y 100m2.<br>
# Y precios menores a usd300000.

# %%
df_filtrado = df_prop.loc[(df_prop['superficie_cubierta'] > 10)
            &(df_prop['superficie_cubierta'] < 200) 
            &(df_prop['precio'] < 700000),:]

# %%
sns.jointplot(x="superficie_cubierta", y="precio",size=8, data=df_filtrado);

# %%
df_prop.loc[(df_prop['superficie_cubierta'] > 10)&(df_prop['superficie_cubierta'] < 200) &(df_prop['precio'] < 700000),:]\
.plot.scatter(x='superficie_cubierta',y='precio',alpha=0.2,figsize= (15,8))
plt.title("Correlación Precio - Superficie")
plt.ylabel("Precio de la propiedad (usd)") 
plt.xlabel("Superficie total en (m2)")
# Out:
# Text(0.5,0,'Superficie total en (m2)')

# %% [markdown]
# ### Correlación entre variables¶
#
# Exploración de correlación entre las variables de atributos de las propiedades (superficie, piso, habitaciones) y las referidas al precio de las mismas.

# %%
corr = df_prop.loc[:,['precio','superficie_cubierta','ambientes', 'cochera','expensas', 'balcon']].corr()

# %%
plt.title("Correlacion entre variables")
sns.heatmap(corr, center=0, vmin=-1, vmax=1, annot=True, cmap="Blues");

# %% [markdown]
# ¿En qué barrios los precios por $m^2$ son más altos?

# %% [markdown]
# ¿En qué barrios hay una mayor cantidad de viviendas para su venta?

# %% [markdown]
# ¿ En qué barrios hay una mayor dispersión de precios?

# %% [markdown]
# ¿Qué tipo de propiedad presenta los mayores precios? ¿Cuál las mayores dispersiones?

# %% [markdown]
# Continua realizando un análisis exploratorio del dataset...

# %% [markdown]
# ## BONUS: Empezando con regresiones lineales...
#
# Si se atreven, podrían empezar a probar con algunos modelos de regresión no demasiado sofisticados. Seleccionen (o construyan) su variable dependiente ($Y$) y comiencen probando con pocas variables y modelos sencillos.
#
# Usen el estimador `LinearRegression` de submódulo `sklearn.linear_model`.
#
# Recuerden los pasos para comenzar a trabajar con estimadores en Scikit-Learn.
#
# 1. Elegir una clase de modelo importando la clase de estimador apropiado de Scikit-Learn.
# 2. Seleccionar los hiperparámetros del modelo instanciando la clase con los valores deseados.
# 3. Preparar los datos en una matriz de features y un array target, como vimos previamente.
# 4. Ajustar el modelo a los datos invocando el método fit() de la instancia del modelo.
# 5. Aplicar el modelo a nuevos datos:
#     * Para aprendizaje supervisado, frecuentemente predecimos labels para datos nuevos usando el método predict()
#     * Para aprendizaje no supervisado, frecuentemente transformamos o inferimos propiedades de los datos usando los métodos transform() o predict()
#
# ¿Qué pueden decir del ajuste y la capacidad predictiva de sus modelos?

# %%
from sklearn.linear_model import LinearRegression
